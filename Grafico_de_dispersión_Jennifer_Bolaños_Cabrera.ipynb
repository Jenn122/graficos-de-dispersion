# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenn122/graficos-de-dispersion/blob/main/Grafico_de_dispersi%C3%B3n_Jennifer_Bola%C3%B1os_Cabrera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Interaccion de insectos en su habitat y alimentos#

# %%
pip install matplotlip

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [2,10,1,2,1,2,0,1,0,0,2,0,0,0,1,4,4,0,0,0,1,1,1,2,0,2,1,1,0]
y = [2,4,10,4,1,0,2,1,0,1,2,0,0,1,0,1,0,1,0,2,2,0,0,2,0,1,0,1,1]

# %%
plt.scatter(x, y)
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Diagrama interaccion de insectos en su habitat')
# Out:
# Text(0.5, 1.0, 'Diagrama interaccion de insectos en su habitat')

# %%
x = np.random.normal(5.0,6.0,1000)

# %%
y = np.random.normal(10.0,8.0,1000)

# %%
plt.scatter(x,y)
